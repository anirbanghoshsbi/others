# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/others/blob/master/Question_Anwering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Input # for function API
from keras.layers.core import Activation , Dense , Dropout , Permute
from keras.layers.embeddings import Embedding
from keras.layers.merge import add , concatenate,dot
from keras.layers.recurrent import LSTM
from keras.models import Model
from keras.preprocessing.sequence import pad_sequences
from keras.utils import np_utils
import collections
import itertools
import nltk
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# qa1_single-supporting-fact_test.txt   sample_data
# qa1_single-supporting-fact_train.txt

# %%
TRAIN_FILE = "qa1_single-supporting-fact_train.txt"
TEST_FILE = "qa1_single-supporting-fact_test.txt"

def get_data(infile):
    stories, questions, answers = [], [], []
    story_text = []
    fin = open(TRAIN_FILE, "rb")
    for line in fin:
        line = line.decode("utf-8").strip()
        
        lno, text = line.split(" ", 1)
        #print(text)
        #story_text.append(text)
        if "\t" in text:
            question, answer,_= text.split("\t")
            stories.append(story_text)
            questions.append(question)
            answers.append(answer)
            story_text = []
        else:
            story_text.append(text)
    fin.close()
    return stories, questions, answers

data_train = get_data(TRAIN_FILE)
data_test = get_data(TEST_FILE)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def build_vocab(train_data, test_data):
    counter = collections.Counter()
    for stories,_,_ in [train_data, test_data]:
        for story in stories:
            for sent in story:
                for word in nltk.word_tokenize(sent):
                    counter[word.lower()] += 1
    for _,questions,_ in  [train_data, test_data]:                 
                for question in questions:
                    for word in nltk.word_tokenize(question):
                         counter[word.lower()] += 1
    for _,_,answers in  [train_data, test_data]:            
                for answer in answers:
                    for word in nltk.word_tokenize(answer):
                         counter[word.lower()] += 1
    word2idx = {w:(i+1) for i, (w, _) in enumerate(counter.most_common())}
    word2idx["PAD"] = 0
    idx2word = {v:k for k, v in word2idx.items()}
    return word2idx, idx2word

word2idx, idx2word = build_vocab(data_train, data_test)

vocab_size = len(word2idx)

# %%
vocab_size
# Out:
# 22

# %%
def get_maxlens(train_data, test_data):
    story_maxlen, question_maxlen = 0, 0
    for stories,_, _ in [train_data, test_data]:
        for story in stories:
            story_len = 0
            for sent in story:
                swords = nltk.word_tokenize(sent)
                story_len += len(swords)
            if story_len > story_maxlen:
                story_maxlen = story_len
    for _,questions,_ in [train_data, test_data]:           
        for question in questions:
            question_len = len(nltk.word_tokenize(question))
            if question_len > question_maxlen:
                question_maxlen = question_len
    return story_maxlen, question_maxlen

story_maxlen, question_maxlen = get_maxlens(data_train, data_test)

# %%
data_train
# Out:
# ([['Anirban moved to the bathroom.', 'John went to the hallway.'],
#   ['Daniel went back to the hallway.', 'Sandra moved to the garden.'],
#   ['John moved to the office.', 'Sandra journeyed to the bathroom.'],
#   ['Anirban moved to the hallway.', 'Daniel travelled to the office.'],
#   ['John went back to the garden.', 'John moved to the bedroom.'],
#   ['Sandra travelled to the office.', 'Sandra went to the bathroom.'],
#   ['Anirban went to the bedroom.', 'Daniel moved to the hallway.'],
#   ['John went to the garden.', 'John travelled to the office.'],
#   ['Daniel journeyed to the bedroom.', 'Daniel travelled to the hallway.'],
#   ['John went to the bedroom.', 'John travelled to the office.'],
#   ['Anirban went to the bedroom.', 'John journeyed to the bathroom.'],
#   ['Sandra journeyed to the hallway.', 'John journeyed to the garden.'],
#   ['John journeyed to the bathroom.', 'Sandra journeyed to the garden.'],
#   ['Sandra went back to the bedroom.', 'Daniel travelled to the bathroom.'],
#   ['John went to the office.', 'Anirban moved to the office.'],
#   ['Daniel journeyed to the kitchen.', 'Daniel journeyed to the bedroom.'],
#   ['Sandra moved to the garden.', 'Sandra went back to the kitchen.'],
#   ['Daniel travelled to the office.', 'Sandra went back to the hallway.'],
#   ['Daniel journeyed to the hallway.', 'Daniel went to the bathroom.'],
#   ['John travelled to the garden.', 'Daniel moved to the hallway.'],
#   ['Anirban moved to the garden.', 'John journeyed to the bathroom.'],
#   ['Sandra moved to the office.', 'John moved to the kitchen.'],
#   ['Sandra went to the hallway.', 'Anirban travelled to the bedroom.'],
#   ['Anirban moved to the office.', 'John moved to the garden.'],
#   ['John journeyed to the office.', 'Sandra went to the office.'],
#   ['Anirban moved to the garden.', 'Daniel journeyed to the bathroom.'],
#   ['John travelled to the kitchen.', 'John went back to the bedroom.'],
#   ['John moved to the office.', 'Daniel went back to the garden.'],
#   ['John went back to the hallway.', 'Anirban went to the office.'],
#   ['Sandra travelled to the bedroom.', 'John travelled to the garden.'],
#   ['John moved to the bedroom.', 'Anirban moved to the hallway.'],
#   ['Sandra moved to the bedroom.', 'Sandra travelled to the kitchen.'],
#   ['Daniel journeyed to the bathroom.', 'Sandra moved to the bathroom.'],
#   ['Daniel went back to the garden.', 'John moved to the kitchen.'],
#   ['Daniel journeyed to the kitchen.', 'Daniel journeyed to the garden.'],
#   ['Anirban went to the kitchen.', 'John went back to the bedroom.'],
#   ['Anirban went back to the bathroom.', 'Anirban moved to the hallway.'],
#   ['John went to the kitchen.', 'Daniel travelled to the bedroom.'],
#   ['Anirban travelled to the office.', 'Sandra moved to the bedroom.'],
#   ['John moved to the bedroom.', 'Sandra journeyed to the kitchen.'],
#   ['Daniel moved to the hallway.', 'Daniel travelled to the office.'],
#   ['Daniel went to the bedroom.', 'Daniel journeyed to the office.'],
#   ['Sandra went back to the bathroom.', 'Sandra journeyed to the kitchen.'],
#   ['Daniel moved to the bedroom.', 'Daniel journeyed to the hallway.'],
#   ['Sandra travelled to the garden.', 'Sandra went back to the bathroom.'],
#   ['Sandra went to the garden.', 'Sandra journeyed to the bedroom.'],
#   ['Anirban travelled to the bathroom.', 'John journeyed to the bedroom.'],
#   ['Anirban went back to the kitchen.', 'John went to the kitchen.'],
#   ['Daniel travelled to the kitchen.', 'Sandra travelled to the bathroom.'],
#   ['Sandra went back to the garden.', 'John went back to the garden.'],
#   ['Sandra went back to the bathroom.', 'Anirban moved to the garden.'],
#   ['Anirban went back to the hallway.', 'Sandra went to the office.'],
#   ['John went back to the hallway.', 'John travelled to the office.'],
#   ['Sandra journeyed to the hallway.', 'Daniel moved to the office.'],
#   ['Anirban went to the office.', 'Sandra went to the office.'],
#   ['Anirban went back to the office.', 'John went back to the bathroom.'],
#   ['John went to the hallway.', 'Anirban journeyed to the hallway.'],
#   ['Sandra travelled to the hallway.', 'Anirban travelled to the office.'],
#   ['Anirban went back to the hallway.', 'Sandra travelled to the office.'],
#   ['John went to the kitchen.', 'Sandra went to the hallway.'],
#   ['Sandra moved to the hallway.', 'John moved to the hallway.'],
#   ['John journeyed to the bathroom.', 'Daniel went back to the bedroom.'],
#   ['Anirban travelled to the bedroom.', 'Anirban journeyed to the garden.'],
#   ['John travelled to the bedroom.', 'Sandra journeyed to the garden.'],
#   ['John journeyed to the kitchen.', 'Sandra went to the kitchen.'],
#   ['Daniel went to the kitchen.', 'Anirban travelled to the hallway.'],
#   ['Daniel went back to the garden.', 'Anirban went back to the bathroom.'],
#   ['Sandra moved to the hallway.', 'John moved to the garden.'],
#   ['Daniel moved to the kitchen.', 'Anirban travelled to the office.'],
#   ['Daniel travelled to the hallway.', 'Sandra travelled to the bathroom.'],
#   ['Sandra moved to the kitchen.', 'Sandra went back to the garden.'],
#   ['Sandra journeyed to the office.', 'Anirban moved to the office.'],
#   ['Sandra journeyed to the bathroom.', 'Daniel moved to the office.'],
#   ['Daniel went back to the kitchen.', 'Anirban moved to the hallway.'],
#   ['John went to the office.', 'Sandra went to the office.'],
#   ['Sandra went to the garden.', 'Anirban travelled to the bathroom.'],
#   ['Sandra moved to the bathroom.', 'Anirban travelled to the hallway.'],
#   ['Anirban went back to the kitchen.', 'Daniel travelled to the bedroom.'],
#   ['Anirban journeyed to the bedroom.', 'Anirban journeyed to the office.'],
#   ['Anirban went back to the bedroom.', 'Daniel went to the garden.'],
#   ['Anirban journeyed to the garden.', 'Sandra went back to the office.'],
#   ['Sandra went to the bathroom.', 'John travelled to the bathroom.'],
#   ['Sandra moved to the bedroom.', 'Sandra travelled to the hallway.'],
#   ['Anirban moved to the bathroom.', 'John went to the kitchen.'],
#   ['Daniel moved to the bathroom.', 'Daniel went to the office.'],
#   ['Anirban moved to the office.', 'Daniel went to the kitchen.'],
#   ['Sandra went to the bathroom.', 'Daniel moved to the office.'],
#   ['Sandra went to the office.', 'Sandra went to the hallway.'],
#   ['Anirban went to the garden.', 'Daniel moved to the kitchen.'],
#   ['Anirban went back to the kitchen.', 'John journeyed to the hallway.'],
#   ['John went back to the bathroom.', 'Anirban travelled to the bathroom.'],
#   ['Anirban went to the garden.', 'Sandra moved to the garden.'],
#   ['John went to the kitchen.', 'Daniel moved to the bathroom.'],
#   ['Daniel went back to the hallway.', 'Anirban went to the kitchen.'],
#   ['Daniel went to the garden.', 'Daniel travelled to the hallway.'],
#   ['Anirban went back to the bedroom.', 'Anirban travelled to the bathroom.'],
#   ['John travelled to the office.', 'Anirban travelled to the bedroom.'],
#   ['John journeyed to the kitchen.', 'John moved to the hallway.'],
#   ['Daniel moved to the hallway.', 'Anirban went back to the garden.'],
#   ['Daniel went back to the office.', 'Daniel travelled to the kitchen.'],
#   ['Daniel moved to the garden.', 'Anirban went back to the bathroom.'],
#   ['Daniel travelled to the kitchen.', 'Sandra went to the kitchen.'],
#   ['Daniel journeyed to the garden.', 'Anirban journeyed to the kitchen.'],
#   ['Anirban moved to the hallway.', 'John went back to the bedroom.'],
#   ['John moved to the office.', 'John travelled to the bathroom.'],
#   ['Anirban went back to the hallway.', 'Sandra journeyed to the garden.'],
#   ['Sandra travelled to the bathroom.', 'John travelled to the hallway.'],
#   ['John travelled to the garden.', 'Anirban journeyed to the bedroom.'],
#   ['Sandra journeyed to the office.', 'Daniel journeyed to the hallway.'],
#   ['Anirban journeyed to the hallway.', 'Anirban moved to the bedroom.'],
#   ['Sandra journeyed to the kitchen.', 'Sandra journeyed to the garden.'],
#   ['Daniel travelled to the kitchen.', 'Anirban moved to the bedroom.'],
#   ['Sandra moved to the bedroom.', 'John travelled to the garden.'],
#   ['Sandra went back to the kitchen.', 'John journeyed to the bedroom.'],
#   ['Daniel went back to the bathroom.', 'Sandra journeyed to the bedroom.'],
#   ['Anirban went back to the hallway.', 'Daniel went back to the bedroom.'],
#   ['Sandra moved to the bathroom.', 'Sandra journeyed to the hallway.'],
#   ['Anirban went back to the bedroom.', 'Anirban went back to the garden.'],
#   ['Sandra went back to the bathroom.', 'John went to the office.'],
#   ['Daniel travelled to the garden.', 'Sandra travelled to the hallway.'],
#   ['John went back to the hallway.', 'Sandra journeyed to the kitchen.'],
#   ['Daniel journeyed to the office.', 'John went to the kitchen.'],
#   ['Daniel journeyed to the garden.', 'John travelled to the bedroom.'],
#   ['Daniel journeyed to the office.', 'Daniel went to the bedroom.'],
#   ['Sandra travelled to the hallway.', 'Sandra journeyed to the bedroom.'],
#   ['John moved to the kitchen.', 'Daniel travelled to the garden.'],
#   ['Daniel went to the kitchen.', 'Daniel travelled to the bathroom.'],
#   ['John moved to the bathroom.', 'Anirban journeyed to the bathroom.'],
#   ['Anirban went to the kitchen.', 'Daniel journeyed to the garden.'],
#   ['Daniel went to the kitchen.', 'John went to the hallway.'],
#   ['Sandra went back to the kitchen.', 'Sandra travelled to the bathroom.'],
#   ['John travelled to the garden.', 'Daniel moved to the hallway.'],
#   ['John went to the kitchen.', 'Daniel journeyed to the garden.'],
#   ['Daniel journeyed to the hallway.', 'Sandra journeyed to the garden.'],
#   ['John went back to the hallway.', 'Anirban travelled to the office.'],
#   ['Daniel moved to the bedroom.', 'John went back to the garden.'],
#   ['John travelled to the bathroom.', 'John travelled to the garden.'],
#   ['John went to the kitchen.', 'Daniel journeyed to the garden.'],
#   ['John went back to the garden.', 'Sandra went back to the kitchen.'],
#   ['Daniel journeyed to the hallway.', 'Daniel moved to the bathroom.'],
#   ['Anirban travelled to the hallway.', 'Anirban moved to the garden.'],
#   ['Sandra went to the kitchen.', 'Sandra moved to the bathroom.'],
#   ['Daniel went back to the bedroom.', 'John went back to the office.'],
#   ['Anirban went back to the office.', 'Anirban went to the bathroom.'],
#   ['Daniel went back to the kitchen.', 'Anirban moved to the kitchen.'],
#   ['Daniel went to the office.', 'John journeyed to the garden.'],
#   ['John travelled to the bathroom.', 'Daniel moved to the bedroom.'],
#   ['Anirban travelled to the kitchen.', 'John journeyed to the kitchen.'],
#   ['John travelled to the office.', 'Sandra moved to the office.'],
#   ['John moved to the garden.', 'Anirban journeyed to the bedroom.'],
#   ['Sandra journeyed to the hallway.', 'Daniel travelled to the hallway.'],
#   ['John travelled to the hallway.', 'Sandra went to the bedroom.'],
#   ['John travelled to the office.', 'Sandra went to the kitchen.'],
#   ['Anirban moved to the office.', 'Daniel moved to the office.'],
#   ['Daniel went back to the bathroom.', 'Daniel travelled to the office.'],
#   ['Anirban went to the bathroom.', 'John travelled to the hallway.'],
#   ['John moved to the kitchen.', 'Anirban went back to the hallway.'],
#   ['Daniel went back to the bedroom.', 'Anirban journeyed to the garden.'],
#   ['Anirban went back to the office.', 'Daniel went back to the bathroom.'],
#   ['Sandra moved to the hallway.', 'John went back to the bedroom.'],
#   ['Daniel journeyed to the bedroom.', 'John went to the kitchen.'],
#   ['Anirban moved to the office.', 'Sandra travelled to the bathroom.'],
#   ['Anirban went to the kitchen.', 'Sandra journeyed to the bedroom.'],
#   ['Sandra journeyed to the office.', 'Daniel went back to the bathroom.'],
#   ['Anirban went back to the office.', 'John went back to the office.'],
#   ['Anirban moved to the garden.', 'John went to the bedroom.'],
#   ['Daniel journeyed to the kitchen.', 'Sandra went to the bathroom.'],
#   ['Daniel journeyed to the bathroom.', 'Daniel moved to the garden.'],
#   ['Daniel went to the kitchen.', 'Anirban journeyed to the bathroom.'],
#   ['Sandra travelled to the garden.', 'Sandra went to the hallway.'],
#   ['Sandra travelled to the office.', 'Sandra travelled to the bathroom.'],
#   ['Anirban went back to the hallway.', 'Anirban travelled to the bathroom.'],
#   ['Daniel went to the bedroom.', 'Anirban went to the office.'],
#   ['Anirban travelled to the hallway.', 'John moved to the garden.'],
#   ['Sandra journeyed to the office.', 'Sandra moved to the bathroom.'],
#   ['Sandra journeyed to the garden.', 'Anirban travelled to the hallway.'],
#   ['John travelled to the bathroom.', 'Sandra went back to the kitchen.'],
#   ['Daniel travelled to the bathroom.', 'Daniel travelled to the kitchen.'],
#   ['John went back to the hallway.', 'John travelled to the bathroom.'],
#   ['Anirban journeyed to the bathroom.', 'Anirban travelled to the bedroom.'],
#   ['John went to the office.', 'Daniel journeyed to the kitchen.'],
#   ['John travelled to the bedroom.', 'John moved to the garden.'],
#   ['Daniel journeyed to the bathroom.', 'John journeyed to the bedroom.'],
#   ['Sandra journeyed to the kitchen.', 'Anirban moved to the garden.'],
#   ['Sandra journeyed to the bathroom.', 'Sandra went back to the bedroom.'],
#   ['Daniel went back to the bedroom.', 'Sandra travelled to the bedroom.'],
#   ['Sandra went to the office.', 'Anirban went to the office.'],
#   ['John journeyed to the garden.', 'Anirban journeyed to the garden.'],
#   ['Daniel travelled to the bathroom.', 'John moved to the kitchen.'],
#   ['Sandra went back to the kitchen.', 'Daniel journeyed to the hallway.'],
#   ['Daniel moved to the bathroom.', 'John moved to the office.'],
#   ['Anirban went back to the office.', 'John went back to the hallway.'],
#   ['Anirban moved to the hallway.', 'Anirban journeyed to the kitchen.'],
#   ['Daniel went to the office.', 'Daniel moved to the bedroom.'],
#   ['Sandra journeyed to the hallway.', 'Daniel travelled to the garden.'],
#   ['Anirban travelled to the hallway.', 'Sandra went to the garden.'],
#   ['Daniel travelled to the bedroom.', 'Anirban went to the bedroom.'],
#   ['Daniel moved to the hallway.', 'John travelled to the bathroom.'],
#   ['Daniel journeyed to the bathroom.', 'John journeyed to the office.'],
#   ['Anirban went back to the garden.', 'John went to the kitchen.'],
#   ['Daniel travelled to the kitchen.', 'Daniel journeyed to the garden.'],
#   ['John journeyed to the office.', 'John travelled to the garden.'],
#   ['Daniel moved to the office.', 'John went to the hallway.'],
#   ['John moved to the office.', 'Daniel journeyed to the kitchen.'],
#   ['Daniel went to the garden.', 'John went back to the bathroom.'],
#   ['Anirban went to the bathroom.', 'John went to the kitchen.'],
#   ['Daniel moved to the office.', 'Daniel moved to the bathroom.'],
#   ['Sandra travelled to the bathroom.', 'Anirban travelled to the kitchen.'],
#   ['Anirban went to the garden.', 'Sandra moved to the bedroom.'],
#   ['Sandra journeyed to the kitchen.', 'Daniel travelled to the garden.'],
#   ['Daniel moved to the garden.', 'John went to the kitchen.'],
#   ['Anirban went to the office.', 'Sandra travelled to the bedroom.'],
#   ['Anirban went to the bathroom.', 'John journeyed to the bathroom.'],
#   ['Anirban went back to the office.', 'John went back to the kitchen.'],
#   ['John moved to the office.', 'Anirban journeyed to the bathroom.'],
#   ['Anirban travelled to the kitchen.', 'Anirban moved to the bedroom.'],
#   ['Anirban went to the hallway.', 'Sandra went back to the bathroom.'],
#   ['John went to the bedroom.', 'Daniel travelled to the garden.'],
#   ['Daniel went to the hallway.', 'Sandra went to the office.'],
#   ['Sandra journeyed to the bedroom.', 'John travelled to the bathroom.'],
#   ['John journeyed to the kitchen.', 'John journeyed to the garden.'],
#   ['Anirban went back to the bathroom.', 'Anirban moved to the garden.'],
#   ['Daniel travelled to the bedroom.', 'John moved to the kitchen.'],
#   ['John journeyed to the hallway.', 'Anirban went back to the bathroom.'],
#   ['John journeyed to the bathroom.', 'Sandra moved to the kitchen.'],
#   ['Anirban journeyed to the office.', 'Daniel journeyed to the bedroom.'],
#   ['Anirban went to the bedroom.', 'Sandra went to the bedroom.'],
#   ['John went back to the hallway.', 'Daniel went back to the bathroom.'],
#   ['Anirban travelled to the garden.', 'Daniel moved to the hallway.'],
#   ['Sandra travelled to the office.', 'Daniel moved to the bathroom.'],
#   ['Anirban moved to the kitchen.', 'Sandra moved to the kitchen.'],
#   ['Anirban went to the garden.', 'John moved to the bedroom.'],
#   ['Anirban journeyed to the office.', 'Anirban went to the bathroom.'],
#   ['Sandra travelled to the garden.', 'Daniel went back to the hallway.'],
#   ['Daniel went to the bedroom.', 'Sandra journeyed to the hallway.'],
#   ['John went to the kitchen.', 'John went to the hallway.'],
#   ['John travelled to the bathroom.', 'Sandra travelled to the kitchen.'],
#   ['John journeyed to the garden.', 'Sandra went back to the bedroom.'],
#   ['Anirban moved to the hallway.', 'Anirban went to the bedroom.'],
#   ['Anirban went back to the garden.', 'Sandra travelled to the hallway.'],
#   ['Daniel went back to the bathroom.', 'Anirban journeyed to the office.'],
#   ['Sandra went back to the garden.', 'Daniel moved to the garden.'],
#   ['Daniel journeyed to the hallway.', 'John moved to the garden.'],
#   ['Sandra went back to the hallway.', 'Anirban went back to the bedroom.'],
#   ['John journeyed to the office.', 'John went to the bathroom.'],
#   ['Sandra moved to the bathroom.', 'Daniel journeyed to the garden.'],
#   ['Anirban journeyed to the bathroom.', 'Sandra moved to the hallway.'],
#   ['Daniel moved to the office.', 'Daniel went to the garden.'],
#   ['John travelled to the bathroom.', 'Anirban moved to the bedroom.'],
#   ['Sandra went back to the bathroom.', 'Sandra went to the garden.'],
#   ['John journeyed to the hallway.', 'Daniel journeyed to the hallway.'],
#   ['Daniel went to the office.', 'Sandra moved to the bedroom.'],
#   ['John went to the bedroom.', 'Daniel went back to the kitchen.'],
#   ['John journeyed to the kitchen.', 'Anirban went to the hallway.'],
#   ['Sandra went back to the bathroom.', 'Anirban went to the office.'],
#   ['Daniel journeyed to the office.', 'Anirban went back to the garden.'],
#   ['Daniel went back to the garden.', 'John moved to the hallway.'],
#   ['John travelled to the bathroom.', 'Anirban moved to the kitchen.'],
#   ['Daniel travelled to the bathroom.', 'Sandra journeyed to the bedroom.'],
#   ['Daniel journeyed to the garden.', 'Sandra travelled to the office.'],
#   ['Daniel went back to the bathroom.', 'John moved to the bathroom.'],
#   ['Anirban journeyed to the bathroom.', 'Sandra went to the kitchen.'],
#   ['Anirban went back to the kitchen.', 'Daniel travelled to the office.'],
#   ['Sandra went back to the office.', 'Anirban went back to the garden.'],
#   ['Anirban moved to the bedroom.', 'Daniel moved to the hallway.'],
#   ['Sandra went to the hallway.', 'Sandra journeyed to the kitchen.'],
#   ['Sandra travelled to the garden.', 'Anirban journeyed to the garden.'],
#   ['Daniel went back to the bathroom.', 'Daniel went to the garden.'],
#   ['John went back to the garden.', 'John travelled to the bedroom.'],
#   ['Anirban went to the kitchen.', 'Sandra moved to the hallway.'],
#   ['John went back to the garden.', 'Sandra went back to the bedroom.'],
#   ['Sandra went to the bathroom.', 'John went back to the kitchen.'],
#   ['Anirban went back to the hallway.', 'Daniel travelled to the kitchen.'],
#   ['Sandra went back to the bedroom.', 'Sandra went to the office.'],
#   ['Sandra went to the kitchen.', 'Daniel travelled to the hallway.'],
#   ['Sandra journeyed to the office.', 'John moved to the bathroom.'],
#   ['Daniel moved to the hallway.', 'John moved to the hallway.'],
#   ['John travelled to the kitchen.', 'John went to the bedroom.'],
#   ['Daniel journeyed to the kitchen.', 'John journeyed to the kitchen.'],
#   ['John travelled to the bathroom.', 'John travelled to the kitchen.'],
#   ['Anirban moved to the hallway.', 'John travelled to the hallway.'],
#   ['Daniel travelled to the bedroom.', 'Daniel went to the garden.'],
#   ['John went back to the bathroom.', 'Sandra moved to the hallway.'],
#   ['Daniel moved to the hallway.', 'Anirban went to the office.'],
#   ['Anirban journeyed to the garden.', 'John went to the hallway.'],
#   ['John journeyed to the bathroom.', 'Daniel went back to the kitchen.'],
#   ['John journeyed to the office.', 'Sandra travelled to the bedroom.'],
#   ['Daniel moved to the bathroom.', 'Daniel went to the hallway.'],
#   ['Anirban went back to the office.', 'Anirban went to the bathroom.'],
#   ['Anirban journeyed to the kitchen.', 'Anirban moved to the bedroom.'],
#   ['Anirban journeyed to the bathroom.', 'Anirban moved to the hallway.'],
#   ['Daniel moved to the bathroom.', 'Sandra went back to the bathroom.'],
#   ['Sandra went to the kitchen.', 'Anirban travelled to the kitchen.'],
#   ['Daniel journeyed to the kitchen.', 'Sandra went to the garden.'],
#   ['Daniel went to the bedroom.', 'Sandra went to the bathroom.'],
#   ['Anirban travelled to the garden.', 'John journeyed to the bathroom.'],
#   ['Anirban journeyed to the kitchen.', 'John travelled to the kitchen.'],
#   ['Anirban moved to the bedroom.', 'Anirban travelled to the garden.'],
#   ['John went back to the bedroom.', 'Daniel went back to the bedroom.'],
#   ['John went back to the kitchen.', 'Anirban went to the bedroom.'],
#   ['Anirban went back to the bedroom.', 'Daniel travelled to the office.'],
#   ['Anirban journeyed to the hallway.', 'Sandra went back to the garden.'],
#   ['Anirban moved to the garden.', 'Daniel moved to the kitchen.'],
#   ['John went to the office.', 'Sandra journeyed to the office.'],
#   ['John travelled to the hallway.', 'Sandra travelled to the bathroom.'],
#   ['Sandra journeyed to the bathroom.', 'John went to the hallway.'],
#   ['Anirban travelled to the garden.', 'Anirban went back to the kitchen.'],
#   ['Daniel travelled to the bathroom.', 'John moved to the garden.'],
#   ['Daniel moved to the kitchen.', 'Sandra journeyed to the hallway.'],
#   ['Daniel moved to the bedroom.', 'John went back to the office.'],
#   ['John went back to the kitchen.', 'John moved to the office.'],
#   ['John journeyed to the garden.', 'Sandra journeyed to the bedroom.'],
#   ['Anirban went back to the garden.', 'John journeyed to the bedroom.'],
#   ['John went to the hallway.', 'Sandra went back to the hallway.'],
#   ['John journeyed to the bathroom.', 'Anirban went to the hallway.'],
#   ['John went back to the bedroom.', 'John moved to the kitchen.'],
#   ['John journeyed to the garden.', 'Anirban went back to the hallway.'],
#   ['Daniel went back to the bedroom.', 'John went to the bedroom.'],
#   ['Sandra travelled to the garden.', 'Daniel went back to the office.'],
#   ['Anirban went back to the bedroom.', 'Daniel journeyed to the kitchen.'],
#   ['Anirban went to the garden.', 'Daniel journeyed to the bathroom.'],
#   ['John went to the office.', 'Anirban moved to the hallway.'],
#   ['John went to the bathroom.', 'Daniel moved to the kitchen.'],
#   ['John went to the kitchen.', 'Daniel went to the bedroom.'],
#   ['Anirban went to the kitchen.', 'Sandra journeyed to the garden.'],
#   ['Daniel went back to the kitchen.', 'Daniel moved to the garden.'],
#   ['Sandra journeyed to the bedroom.', 'Anirban moved to the bathroom.'],
#   ['John went back to the office.', 'Daniel went back to the bathroom.'],
#   ['Daniel travelled to the bedroom.', 'Sandra went to the bathroom.'],
#   ['Daniel went back to the hallway.', 'Sandra travelled to the kitchen.'],
#   ['Sandra moved to the bedroom.', 'Anirban journeyed to the bedroom.'],
#   ['Anirban moved to the bathroom.', 'Daniel travelled to the bedroom.'],
#   ['Anirban moved to the bedroom.', 'Sandra went to the kitchen.'],
#   ['Sandra went to the garden.', 'Daniel moved to the kitchen.'],
#   ['Sandra went back to the bedroom.', 'Sandra went to the hallway.'],
#   ['John journeyed to the bedroom.', 'Daniel moved to the office.'],
#   ['John went to the hallway.', 'John journeyed to the kitchen.'],
#   ['Anirban went to the office.', 'Daniel went back to the bedroom.'],
#   ['Daniel moved to the hallway.', 'John went to the bedroom.'],
#   ['Sandra moved to the kitchen.', 'Daniel moved to the office.'],
#   ['Anirban journeyed to the office.', 'Daniel went to the bedroom.'],
#   ['Daniel journeyed to the bathroom.', 'Sandra went to the bedroom.'],
#   ['Anirban journeyed to the hallway.', 'Daniel travelled to the kitchen.'],
#   ['Sandra journeyed to the bathroom.', 'Sandra moved to the bedroom.'],
#   ['John moved to the garden.', 'Daniel travelled to the bathroom.'],
#   ['John journeyed to the garden.', 'John travelled to the office.'],
#   ['Anirban travelled to the hallway.', 'John journeyed to the bedroom.'],
#   ['Daniel moved to the garden.', 'Anirban journeyed to the bedroom.'],
#   ['Daniel went to the office.', 'Daniel journeyed to the kitchen.'],
#   ['John travelled to the hallway.', 'Daniel went back to the garden.'],
#   ['Daniel journeyed to the garden.', 'John moved to the garden.'],
#   ['Daniel travelled to the bathroom.', 'Sandra went back to the garden.'],
#   ['Daniel went back to the office.', 'Anirban journeyed to the bedroom.'],
#   ['Daniel went to the kitchen.', 'John journeyed to the kitchen.'],
#   ['Sandra journeyed to the kitchen.', 'Sandra went back to the office.'],
#   ['Sandra moved to the bathroom.', 'John journeyed to the office.'],
#   ['Sandra went back to the hallway.', 'John moved to the bedroom.'],
#   ['Daniel moved to the garden.', 'Daniel went back to the kitchen.'],
#   ['Anirban went back to the bedroom.', 'John went back to the office.'],
#   ['Anirban travelled to the office.', 'Sandra went back to the bedroom.'],
#   ['Sandra journeyed to the bathroom.', 'Anirban travelled to the hallway.'],
#   ['Sandra moved to the kitchen.', 'Anirban journeyed to the garden.'],
#   ['John travelled to the office.', 'John went to the hallway.'],
#   ['Daniel travelled to the bedroom.', 'John went back to the office.'],
#   ['Sandra went back to the bedroom.', 'John went to the bedroom.'],
#   ['Anirban went to the hallway.', 'Daniel went to the bathroom.'],
#   ['Anirban went to the bedroom.', 'Anirban went to the kitchen.'],
#   ['Daniel moved to the garden.', 'Daniel went to the office.'],
#   ['John went to the kitchen.', 'Sandra travelled to the garden.'],
#   ['Anirban journeyed to the hallway.', 'Sandra went back to the hallway.'],
#   ['Anirban went back to the hallway.', 'Sandra journeyed to the bedroom.'],
#   ['Sandra travelled to the kitchen.', 'John went back to the hallway.'],
#   ['Daniel went back to the office.', 'Anirban moved to the kitchen.'],
#   ['Daniel went back to the bathroom.', 'Daniel travelled to the office.'],
#   ['Daniel went to the hallway.', 'Daniel went to the bathroom.'],
#   ['Daniel went to the office.', 'Anirban went back to the office.'],
#   ['Sandra travelled to the bedroom.', 'John journeyed to the bedroom.'],
#   ['Anirban moved to the bedroom.', 'Daniel travelled to the kitchen.'],
#   ['Sandra journeyed to the garden.', 'Sandra journeyed to the office.'],
#   ['Sandra journeyed to the garden.', 'Sandra travelled to the hallway.'],
#   ['John travelled to the bedroom.', 'Anirban moved to the bedroom.'],
#   ['John went back to the bathroom.', 'Sandra moved to the bathroom.'],
#   ['John journeyed to the office.', 'Daniel journeyed to the office.'],
#   ['John went back to the garden.', 'John journeyed to the bedroom.'],
#   ['John went to the bathroom.', 'Anirban moved to the office.'],
#   ['John went to the bathroom.', 'John moved to the office.'],
#   ['John went to the hallway.', 'Sandra journeyed to the hallway.'],
#   ['John journeyed to the bathroom.', 'Daniel went to the bathroom.'],
#   ['Sandra moved to the garden.', 'John moved to the office.'],
#   ['Sandra moved to the hallway.', 'Daniel went to the kitchen.'],
#   ['Anirban travelled to the garden.', 'Daniel moved to the bathroom.'],
#   ['John went to the hallway.', 'Sandra went back to the kitchen.'],
#   ['Daniel went back to the garden.', 'John travelled to the garden.'],
#   ['Anirban went to the bathroom.', 'Sandra went back to the hallway.'],
#   ['Daniel travelled to the office.', 'Daniel travelled to the bathroom.'],
#   ['John moved to the hallway.', 'Anirban travelled to the hallway.'],
#   ['Sandra went to the bedroom.', 'Sandra went back to the hallway.'],
#   ['John went back to the office.', 'Daniel travelled to the kitchen.'],
#   ['John travelled to the hallway.', 'Anirban journeyed to the kitchen.'],
#   ['John travelled to the office.', 'John travelled to the kitchen.'],
#   ['Anirban moved to the bedroom.', 'Sandra went back to the garden.'],
#   ['Daniel went to the bedroom.', 'Anirban journeyed to the hallway.'],
#   ['Anirban went back to the bathroom.', 'Daniel journeyed to the office.'],
#   ['Daniel went back to the bedroom.', 'Anirban went back to the office.'],
#   ['John journeyed to the garden.', 'John moved to the office.'],
#   ['John travelled to the bathroom.', 'Sandra moved to the hallway.'],
#   ['Daniel travelled to the kitchen.', 'Daniel travelled to the hallway.'],
#   ['John moved to the hallway.', 'Anirban went to the hallway.'],
#   ['Daniel journeyed to the office.', 'Daniel journeyed to the kitchen.'],
#   ['Anirban moved to the office.', 'Anirban went to the bedroom.'],
#   ['Daniel journeyed to the hallway.', 'Sandra travelled to the kitchen.'],
#   ['John journeyed to the hallway.', 'Sandra travelled to the office.'],
#   ['Sandra went to the hallway.', 'Daniel journeyed to the office.'],
#   ['Daniel went back to the bedroom.', 'Sandra moved to the bedroom.'],
#   ['John moved to the office.', 'Daniel travelled to the kitchen.'],
#   ['Sandra travelled to the bedroom.', 'Anirban went to the hallway.'],
#   ['Sandra went to the office.', 'Sandra journeyed to the kitchen.'],
#   ['Sandra travelled to the bathroom.', 'Daniel journeyed to the office.'],
#   ['John went back to the hallway.', 'Daniel journeyed to the bedroom.'],
#   ['Sandra moved to the garden.', 'Anirban went back to the bathroom.'],
#   ['Daniel journeyed to the bathroom.', 'Daniel travelled to the hallway.'],
#   ['Sandra went back to the bedroom.', 'Sandra travelled to the bathroom.'],
#   ['John went to the bathroom.', 'Sandra went to the garden.'],
#   ['Anirban journeyed to the hallway.', 'Anirban travelled to the garden.'],
#   ['Anirban went back to the bedroom.', 'John went back to the bedroom.'],
#   ['John moved to the bedroom.', 'Anirban went back to the bedroom.'],
#   ['Daniel moved to the bathroom.', 'Daniel moved to the office.'],
#   ['Sandra journeyed to the bedroom.', 'Anirban moved to the garden.'],
#   ['John went back to the garden.', 'Sandra went to the bathroom.'],
#   ['John travelled to the bedroom.', 'Sandra travelled to the kitchen.'],
#   ['Daniel moved to the garden.', 'Sandra moved to the bedroom.'],
#   ['Daniel journeyed to the hallway.', 'Sandra went to the office.'],
#   ['Daniel moved to the bedroom.', 'John went back to the bathroom.'],
#   ['Sandra travelled to the kitchen.', 'Sandra went back to the bedroom.'],
#   ['John journeyed to the garden.', 'Daniel went back to the garden.'],
#   ['Daniel went back to the office.', 'Anirban went back to the hallway.'],
#   ['Sandra journeyed to the bathroom.', 'Sandra travelled to the hallway.'],
#   ['Anirban went back to the office.', 'Daniel went to the bathroom.'],
#   ['Anirban moved to the bathroom.', 'John went to the bedroom.'],
#   ['Daniel went back to the bedroom.', 'Sandra travelled to the office.'],
#   ['John went to the office.', 'Anirban journeyed to the garden.'],
#   ['John went to the garden.', 'John journeyed to the hallway.'],
#   ['Sandra went to the hallway.', 'John went to the bedroom.'],
#   ['Sandra moved to the bedroom.', 'Anirban travelled to the hallway.'],
#   ['John travelled to the garden.', 'Daniel went back to the bedroom.'],
#   ['Sandra travelled to the bathroom.', 'Anirban travelled to the office.'],
#   ['Sandra travelled to the hallway.', 'Anirban moved to the bathroom.'],
#   ['John went to the office.', 'Sandra journeyed to the office.'],
#   ['John went back to the bathroom.', 'John travelled to the kitchen.'],
#   ['John moved to the office.', 'Daniel went back to the kitchen.'],
#   ['Anirban went back to the bedroom.', 'Anirban moved to the bathroom.'],
#   ['Sandra travelled to the bedroom.', 'Sandra went to the office.'],
#   ['Daniel went to the garden.', 'Daniel journeyed to the bathroom.'],
#   ['Sandra moved to the hallway.', 'John journeyed to the kitchen.'],
#   ['Sandra went to the office.', 'John moved to the bathroom.'],
#   ['Daniel went to the kitchen.', 'Sandra went to the kitchen.'],
#   ['John moved to the bedroom.', 'Anirban went to the hallway.'],
#   ['Anirban travelled to the kitchen.', 'Sandra journeyed to the hallway.'],
#   ['Sandra travelled to the bedroom.', 'Daniel journeyed to the garden.'],
#   ['Sandra journeyed to the office.', 'Sandra journeyed to the kitchen.'],
#   ['Daniel travelled to the kitchen.', 'Daniel went to the hallway.'],
#   ['Anirban travelled to the hallway.', 'John went to the hallway.'],
#   ['Sandra moved to the garden.', 'Anirban went to the kitchen.'],
#   ['John moved to the garden.', 'John went back to the bathroom.'],
#   ['Anirban went to the hallway.', 'Daniel moved to the kitchen.'],
#   ['John went back to the hallway.', 'Daniel journeyed to the bedroom.'],
#   ['Sandra went back to the bedroom.', 'Sandra moved to the bathroom.'],
#   ['John went to the office.', 'John travelled to the garden.'],
#   ['John went to the bedroom.', 'Anirban went back to the kitchen.'],
#   ['Anirban went back to the garden.', 'Anirban journeyed to the bedroom.'],
#   ['Daniel journeyed to the kitchen.', 'Daniel went back to the bedroom.'],
#   ['Sandra travelled to the bathroom.', 'Sandra moved to the kitchen.'],
#   ['Sandra journeyed to the bedroom.', 'Anirban went to the kitchen.'],
#   ['Daniel moved to the bathroom.', 'Sandra moved to the office.'],
#   ['Sandra travelled to the hallway.', 'John went to the kitchen.'],
#   ['John went to the hallway.', 'Daniel moved to the garden.'],
#   ['John went back to the bedroom.', 'Anirban journeyed to the garden.'],
#   ['Sandra went back to the kitchen.', 'Daniel went to the hallway.'],
#   ['John went back to the bathroom.', 'Daniel went back to the kitchen.'],
#   ['Daniel went to the bedroom.', 'John travelled to the hallway.'],
#   ['Daniel travelled to the bathroom.', 'Sandra moved to the kitchen.'],
#   ['Anirban moved to the bedroom.', 'Anirban journeyed to the garden.'],
#   ['Anirban moved to the hallway.', 'Sandra went back to the hallway.'],
#   ['Anirban went to the kitchen.', 'John went to the garden.'],
#   ['John moved to the office.', 'Daniel went back to the bedroom.'],
#   ['Sandra moved to the office.', 'John went back to the garden.'],
#   ['Daniel travelled to the office.', 'Sandra journeyed to the bathroom.'],
#   ['John moved to the kitchen.', 'John moved to the bathroom.'],
#   ['Sandra journeyed to the hallway.', 'Daniel went to the bathroom.'],
#   ['Sandra went to the bathroom.', 'Sandra journeyed to the hallway.'],
#   ['John travelled to the kitchen.', 'John went to the bathroom.'],
#   ['Sandra travelled to the bedroom.', 'Sandra journeyed to the garden.'],
#   ['John journeyed to the bedroom.', 'John journeyed to the bathroom.'],
#   ['Anirban travelled to the kitchen.', 'Anirban journeyed to the garden.'],
#   ['John journeyed to the office.', 'Daniel journeyed to the bathroom.'],
#   ['Anirban moved to the bedroom.', 'Sandra travelled to the garden.'],
#   ['Sandra journeyed to the kitchen.', 'Sandra moved to the garden.'],
#   ['Sandra travelled to the kitchen.', 'Daniel went to the garden.'],
#   ['John went to the hallway.', 'Anirban travelled to the hallway.'],
#   ['Daniel went back to the hallway.', 'Daniel moved to the bathroom.'],
#   ['Daniel went to the bedroom.', 'Anirban went to the kitchen.'],
#   ['Anirban travelled to the bedroom.', 'John journeyed to the bathroom.'],
#   ['Sandra moved to the garden.', 'Sandra went to the office.'],
#   ['Daniel went back to the hallway.', 'Sandra moved to the kitchen.'],
#   ['Anirban travelled to the bathroom.', 'Sandra journeyed to the bedroom.'],
#   ['Daniel went to the kitchen.', 'Daniel went back to the garden.'],
#   ['Daniel went back to the office.', 'John travelled to the kitchen.'],
#   ['Sandra moved to the bedroom.', 'John went to the office.'],
#   ['Anirban journeyed to the office.', 'Sandra moved to the kitchen.'],
#   ['Sandra moved to the office.', 'John travelled to the garden.'],
#   ['Sandra journeyed to the hallway.', 'Anirban travelled to the bathroom.'],
#   ['John moved to the office.', 'Anirban moved to the bedroom.'],
#   ['Anirban journeyed to the kitchen.', 'Anirban went back to the bathroom.'],
#   ['John moved to the bathroom.', 'Anirban went back to the kitchen.'],
#   ['Sandra journeyed to the bedroom.', 'Daniel went back to the kitchen.'],
#   ['Sandra moved to the hallway.', 'John went back to the hallway.'],
#   ['Daniel moved to the garden.', 'Daniel went to the bathroom.'],
#   ['Daniel moved to the hallway.', 'Sandra went to the kitchen.'],
#   ['Daniel journeyed to the kitchen.', 'Daniel went to the garden.'],
#   ['Daniel moved to the bathroom.', 'Anirban went to the office.'],
#   ['Sandra travelled to the office.', 'Sandra went to the garden.'],
#   ['Anirban went back to the garden.', 'Daniel went to the kitchen.'],
#   ['Sandra moved to the bathroom.', 'Sandra travelled to the garden.'],
#   ['Anirban went to the bedroom.', 'Anirban went to the garden.'],
#   ['Sandra moved to the hallway.', 'Anirban moved to the bathroom.'],
#   ['Daniel journeyed to the kitchen.', 'John went back to the kitchen.'],
#   ['Anirban went to the hallway.', 'John moved to the office.'],
#   ['Daniel travelled to the hallway.', 'Anirban went to the garden.'],
#   ['Anirban went back to the office.', 'Anirban went to the garden.'],
#   ['Sandra moved to the bathroom.', 'Daniel moved to the office.'],
#   ['John went to the kitchen.', 'John moved to the garden.'],
#   ['Daniel went back to the bedroom.', 'Sandra moved to the office.'],
#   ['Sandra journeyed to the garden.', 'John moved to the bathroom.'],
#   ['Daniel travelled to the bathroom.', 'John travelled to the garden.'],
#   ['Anirban went back to the bathroom.', 'Sandra travelled to the hallway.'],
#   ['Sandra went to the garden.', 'Anirban travelled to the garden.'],
#   ['Sandra travelled to the kitchen.', 'Daniel went back to the bedroom.'],
#   ['Daniel went to the kitchen.', 'Sandra travelled to the garden.'],
#   ['Anirban went back to the bedroom.', 'Anirban travelled to the kitchen.'],
#   ['John travelled to the bathroom.', 'Anirban travelled to the hallway.'],
#   ['Daniel travelled to the bathroom.', 'Sandra moved to the hallway.'],
#   ['Sandra went to the office.', 'Anirban journeyed to the kitchen.'],
#   ['Daniel went to the kitchen.', 'Anirban went back to the garden.'],
#   ['Daniel moved to the bedroom.', 'Sandra travelled to the garden.'],
#   ['Daniel went back to the hallway.', 'John moved to the bedroom.'],
#   ['Anirban travelled to the bedroom.', 'Daniel travelled to the office.'],
#   ['Daniel journeyed to the hallway.', 'Anirban travelled to the hallway.'],
#   ['Sandra travelled to the kitchen.', 'Anirban travelled to the kitchen.'],
#   ['John journeyed to the garden.', 'Daniel went to the bathroom.'],
#   ['Daniel moved to the garden.', 'John went to the kitchen.'],
#   ['Sandra went back to the office.', 'Sandra moved to the bathroom.'],
#   ['Anirban travelled to the office.', 'Anirban moved to the hallway.'],
#   ['Anirban went to the bedroom.', 'Anirban journeyed to the office.'],
#   ['Anirban journeyed to the bathroom.', 'Sandra travelled to the garden.'],
#   ['Anirban went to the kitchen.', 'John travelled to the hallway.'],
#   ['Sandra went to the kitchen.', 'Daniel went back to the bathroom.'],
#   ['Daniel journeyed to the hallway.', 'Anirban journeyed to the kitchen.'],
#   ['Sandra travelled to the bedroom.', 'Sandra went to the office.'],
#   ['Anirban moved to the office.', 'Sandra went back to the hallway.'],
#   ['John travelled to the bedroom.', 'Daniel journeyed to the office.'],
#   ['John travelled to the hallway.', 'Anirban travelled to the bathroom.'],
#   ['Sandra went to the bedroom.', 'Daniel moved to the office.'],
#   ['Daniel travelled to the hallway.', 'Daniel journeyed to the bathroom.'],
#   ['Daniel went to the hallway.', 'Anirban journeyed to the office.'],
#   ['Anirban travelled to the bathroom.', 'Sandra journeyed to the garden.'],
#   ['Daniel journeyed to the bedroom.', 'Daniel moved to the kitchen.'],
#   ['Anirban travelled to the kitchen.', 'Anirban moved to the bathroom.'],
#   ['John travelled to the office.', 'Daniel went to the hallway.'],
#   ['John went back to the garden.', 'Sandra travelled to the bathroom.'],
#   ['Sandra journeyed to the office.', 'John went to the bathroom.'],
#   ['Sandra travelled to the bathroom.', 'Sandra moved to the kitchen.'],
#   ['Sandra journeyed to the bathroom.', 'Sandra journeyed to the bedroom.'],
#   ['Sandra journeyed to the hallway.', 'Anirban went to the kitchen.'],
#   ['John went back to the garden.', 'Anirban went to the office.'],
#   ['Daniel journeyed to the office.', 'Anirban went back to the bedroom.'],
#   ['John travelled to the office.', 'Daniel went back to the bedroom.'],
#   ['Sandra travelled to the hallway.', 'Daniel journeyed to the office.'],
#   ['Daniel travelled to the bathroom.', 'Anirban travelled to the garden.'],
#   ['Anirban went to the bedroom.', 'Sandra moved to the office.'],
#   ['Anirban went to the kitchen.', 'Sandra went to the kitchen.'],
#   ['John went back to the hallway.', 'Sandra moved to the bedroom.'],
#   ['Sandra went to the bathroom.', 'Daniel went back to the office.'],
#   ['Sandra went to the kitchen.', 'Sandra moved to the bedroom.'],
#   ['John journeyed to the garden.', 'Anirban travelled to the hallway.'],
#   ['Anirban went to the office.', 'Daniel travelled to the bedroom.'],
#   ['Anirban travelled to the kitchen.', 'Anirban moved to the hallway.'],
#   ['John went to the office.', 'John went back to the garden.'],
#   ['John moved to the hallway.', 'Sandra travelled to the hallway.'],
#   ['Anirban moved to the garden.', 'Daniel journeyed to the hallway.'],
#   ['Daniel went to the bedroom.', 'Anirban travelled to the bedroom.'],
#   ['Anirban journeyed to the office.', 'Sandra travelled to the bathroom.'],
#   ['Sandra travelled to the office.', 'Anirban went back to the hallway.'],
#   ['Daniel went back to the office.', 'Sandra went to the bathroom.'],
#   ['John journeyed to the bedroom.', 'Sandra went back to the office.'],
#   ['Daniel went to the bedroom.', 'Sandra travelled to the garden.'],
#   ['Anirban journeyed to the hallway.', 'Sandra went to the garden.'],
#   ['Sandra journeyed to the hallway.', 'Anirban journeyed to the bathroom.'],
#   ['John went to the bathroom.', 'Anirban went back to the kitchen.'],
#   ['Daniel went back to the bedroom.', 'Sandra travelled to the bathroom.'],
#   ['Sandra journeyed to the bedroom.', 'Sandra went to the office.'],
#   ['Anirban went back to the bedroom.', 'Anirban travelled to the garden.'],
#   ['John journeyed to the kitchen.', 'Sandra went back to the office.'],
#   ['Anirban journeyed to the bedroom.', 'Sandra travelled to the bathroom.'],
#   ['Daniel journeyed to the garden.', 'Anirban went back to the hallway.'],
#   ['John moved to the bedroom.', 'Anirban travelled to the kitchen.'],
#   ['Sandra went back to the garden.', 'Sandra went to the hallway.'],
#   ['Anirban went back to the garden.', 'Sandra journeyed to the office.'],
#   ['Sandra travelled to the hallway.', 'Sandra moved to the bedroom.'],
#   ['Daniel moved to the office.', 'Anirban journeyed to the hallway.'],
#   ['Anirban journeyed to the bedroom.', 'Daniel went back to the kitchen.'],
#   ['Sandra journeyed to the garden.', 'Sandra journeyed to the kitchen.'],
#   ['Daniel journeyed to the bedroom.', 'Sandra moved to the garden.'],
#   ['Anirban journeyed to the office.', 'Anirban journeyed to the bathroom.'],
#   ['Daniel journeyed to the garden.', 'Anirban went back to the bedroom.'],
#   ['Sandra went back to the kitchen.', 'Sandra travelled to the bedroom.'],
#   ['Daniel went to the hallway.', 'Daniel moved to the bedroom.'],
#   ['Sandra moved to the office.', 'Daniel journeyed to the hallway.'],
#   ['John journeyed to the bathroom.', 'Sandra went to the garden.'],
#   ['John moved to the garden.', 'Anirban journeyed to the garden.'],
#   ['Anirban went to the office.', 'Sandra journeyed to the hallway.'],
#   ['John travelled to the garden.', 'Daniel journeyed to the bedroom.'],
#   ['Sandra went back to the garden.', 'Anirban went to the kitchen.'],
#   ['John travelled to the kitchen.', 'Sandra moved to the bedroom.'],
#   ['Daniel moved to the garden.', 'Daniel travelled to the bedroom.'],
#   ['Anirban journeyed to the office.', 'Sandra moved to the bathroom.'],
#   ['John travelled to the bathroom.', 'Sandra went to the kitchen.'],
#   ['Daniel went to the garden.', 'Anirban moved to the bedroom.'],
#   ['Sandra moved to the bathroom.', 'John moved to the hallway.'],
#   ['John went back to the kitchen.', 'Daniel journeyed to the hallway.'],
#   ['Daniel went back to the office.', 'Sandra went back to the hallway.'],
#   ['Sandra moved to the office.', 'Anirban went back to the bathroom.'],
#   ['Anirban travelled to the office.', 'Sandra moved to the kitchen.'],
#   ['Sandra moved to the bedroom.', 'Anirban went back to the garden.'],
#   ['John went to the hallway.', 'Daniel went back to the bathroom.'],
#   ['John travelled to the garden.', 'John went back to the bathroom.'],
#   ['Anirban travelled to the garden.', 'Daniel went to the garden.'],
#   ['Anirban journeyed to the kitchen.', 'Anirban went back to the hallway.'],
#   ['Daniel travelled to the office.', 'Daniel moved to the garden.'],
#   ['Sandra went back to the kitchen.', 'John travelled to the bathroom.'],
#   ['Daniel went to the kitchen.', 'Anirban moved to the office.'],
#   ['Anirban went to the office.', 'Sandra travelled to the bathroom.'],
#   ['Sandra went to the hallway.', 'Daniel journeyed to the kitchen.'],
#   ['Sandra travelled to the office.', 'John journeyed to the bedroom.'],
#   ['Daniel moved to the hallway.', 'Sandra went to the hallway.'],
#   ['John journeyed to the garden.', 'Sandra went back to the garden.'],
#   ['Sandra journeyed to the garden.', 'Daniel travelled to the bathroom.'],
#   ['Sandra went to the bedroom.', 'Sandra travelled to the hallway.'],
#   ['Sandra travelled to the office.', 'Sandra went back to the garden.'],
#   ['John journeyed to the hallway.', 'John moved to the bedroom.'],
#   ['Sandra moved to the kitchen.', 'John journeyed to the kitchen.'],
#   ['Sandra went to the bedroom.', 'Anirban moved to the bedroom.'],
#   ['John went to the office.', 'Daniel journeyed to the garden.'],
#   ['Anirban travelled to the bathroom.', 'Daniel moved to the hallway.'],
#   ['Daniel travelled to the garden.', 'John moved to the garden.'],
#   ['Anirban went to the garden.', 'Anirban went to the bedroom.'],
#   ['Anirban moved to the kitchen.', 'John travelled to the office.'],
#   ['Daniel went to the hallway.', 'Daniel went back to the kitchen.'],
#   ['Sandra went back to the hallway.', 'John travelled to the bedroom.'],
#   ['Daniel travelled to the garden.', 'Anirban moved to the office.'],
#   ['Anirban journeyed to the garden.', 'John went to the office.'],
#   ['Daniel went to the bedroom.', 'Anirban travelled to the bathroom.'],
#   ['John went back to the kitchen.', 'John travelled to the hallway.'],
#   ['Anirban travelled to the hallway.', 'John travelled to the garden.'],
#   ['Sandra went to the office.', 'Anirban moved to the bathroom.'],
#   ['Anirban journeyed to the garden.', 'John went to the hallway.'],
#   ['John moved to the hallway.', 'Anirban moved to the garden.'],
#   ['Daniel travelled to the garden.', 'Anirban went to the bathroom.'],
#   ['Anirban went back to the bedroom.', 'John went to the kitchen.'],
#   ['Sandra went back to the hallway.', 'John went to the bathroom.'],
#   ['Anirban went back to the office.', 'John travelled to the bedroom.'],
# ...
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is Sandra? ',
#   'Where is John? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Anirban? ',
#   'Where is Sandra? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Sandra? ',
#   'Where is Daniel? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Sandra? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is John? ',
#   'Where is John? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is Sandra? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is John? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is John? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Sandra? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is John? ',
#   'Where is John? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is Sandra? ',
#   'Where is John? ',
#   'Where is Daniel? ',
#   'Where is Sandra? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is Daniel? ',
#   'Where is Anirban? ',
#   'Where is Sandra? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is John? ',
#   'Where is Anirban? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is Daniel? ',
#   'Where is Anirban? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Sandra? ',
#   'Where is Sandra? ',
#   'Where is Daniel? ',
#   'Where is John? ',
#   'Where is Daniel? ',
#   ...],
#  ['bathroom',
#   'hallway',
#   'hallway',
#   'office',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'office',
#   'hallway',
#   'bathroom',
#   'bedroom',
#   'bathroom',
#   'bathroom',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'hallway',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'garden',
#   'kitchen',
#   'hallway',
#   'office',
#   'bathroom',
#   'bedroom',
#   'garden',
#   'hallway',
#   'garden',
#   'hallway',
#   'kitchen',
#   'bathroom',
#   'kitchen',
#   'garden',
#   'kitchen',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'kitchen',
#   'office',
#   'office',
#   'office',
#   'kitchen',
#   'hallway',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'bathroom',
#   'kitchen',
#   'garden',
#   'office',
#   'office',
#   'office',
#   'office',
#   'office',
#   'hallway',
#   'hallway',
#   'office',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'kitchen',
#   'bathroom',
#   'garden',
#   'kitchen',
#   'bathroom',
#   'garden',
#   'office',
#   'bathroom',
#   'hallway',
#   'office',
#   'garden',
#   'hallway',
#   'kitchen',
#   'bedroom',
#   'bedroom',
#   'office',
#   'bathroom',
#   'hallway',
#   'bathroom',
#   'kitchen',
#   'office',
#   'office',
#   'office',
#   'hallway',
#   'kitchen',
#   'bathroom',
#   'bathroom',
#   'kitchen',
#   'kitchen',
#   'hallway',
#   'bathroom',
#   'bedroom',
#   'bedroom',
#   'garden',
#   'kitchen',
#   'garden',
#   'kitchen',
#   'kitchen',
#   'hallway',
#   'hallway',
#   'garden',
#   'bathroom',
#   'bedroom',
#   'garden',
#   'bedroom',
#   'garden',
#   'garden',
#   'bedroom',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'garden',
#   'office',
#   'office',
#   'hallway',
#   'kitchen',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'bathroom',
#   'bathroom',
#   'kitchen',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'bedroom',
#   'garden',
#   'garden',
#   'garden',
#   'bathroom',
#   'garden',
#   'bathroom',
#   'garden',
#   'bathroom',
#   'kitchen',
#   'office',
#   'bathroom',
#   'kitchen',
#   'office',
#   'office',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'kitchen',
#   'office',
#   'bathroom',
#   'kitchen',
#   'kitchen',
#   'bathroom',
#   'office',
#   'bedroom',
#   'bathroom',
#   'kitchen',
#   'bathroom',
#   'office',
#   'bedroom',
#   'garden',
#   'bathroom',
#   'kitchen',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'office',
#   'hallway',
#   'garden',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'bathroom',
#   'bedroom',
#   'kitchen',
#   'kitchen',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'office',
#   'garden',
#   'kitchen',
#   'garden',
#   'bathroom',
#   'office',
#   'kitchen',
#   'bedroom',
#   'garden',
#   'garden',
#   'bedroom',
#   'garden',
#   'bathroom',
#   'kitchen',
#   'garden',
#   'garden',
#   'hallway',
#   'office',
#   'garden',
#   'kitchen',
#   'bathroom',
#   'kitchen',
#   'garden',
#   'kitchen',
#   'garden',
#   'office',
#   'bathroom',
#   'office',
#   'office',
#   'bedroom',
#   'bathroom',
#   'bedroom',
#   'office',
#   'bedroom',
#   'garden',
#   'garden',
#   'garden',
#   'bathroom',
#   'bathroom',
#   'bedroom',
#   'bedroom',
#   'bathroom',
#   'hallway',
#   'office',
#   'kitchen',
#   'kitchen',
#   'bedroom',
#   'garden',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'garden',
#   'bedroom',
#   'garden',
#   'bathroom',
#   'garden',
#   'office',
#   'hallway',
#   'bathroom',
#   'garden',
#   'hallway',
#   'garden',
#   'garden',
#   'bedroom',
#   'hallway',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'kitchen',
#   'office',
#   'garden',
#   'garden',
#   'bedroom',
#   'office',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'office',
#   'hallway',
#   'kitchen',
#   'garden',
#   'garden',
#   'garden',
#   'garden',
#   'garden',
#   'kitchen',
#   'kitchen',
#   'office',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'bedroom',
#   'kitchen',
#   'kitchen',
#   'hallway',
#   'hallway',
#   'hallway',
#   'hallway',
#   'garden',
#   'kitchen',
#   'kitchen',
#   'office',
#   'bathroom',
#   'bedroom',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'garden',
#   'bedroom',
#   'garden',
#   'kitchen',
#   'kitchen',
#   'garden',
#   'kitchen',
#   'bedroom',
#   'office',
#   'kitchen',
#   'office',
#   'kitchen',
#   'hallway',
#   'kitchen',
#   'kitchen',
#   'kitchen',
#   'bedroom',
#   'office',
#   'garden',
#   'bedroom',
#   'hallway',
#   'bathroom',
#   'kitchen',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'garden',
#   'bathroom',
#   'bathroom',
#   'hallway',
#   'garden',
#   'garden',
#   'bedroom',
#   'bathroom',
#   'bathroom',
#   'kitchen',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'garden',
#   'hallway',
#   'office',
#   'kitchen',
#   'office',
#   'hallway',
#   'office',
#   'office',
#   'bathroom',
#   'kitchen',
#   'hallway',
#   'bedroom',
#   'office',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'bedroom',
#   'garden',
#   'bathroom',
#   'garden',
#   'garden',
#   'office',
#   'bathroom',
#   'bedroom',
#   'kitchen',
#   'office',
#   'office',
#   'hallway',
#   'garden',
#   'hallway',
#   'garden',
#   'bedroom',
#   'bathroom',
#   'kitchen',
#   'office',
#   'kitchen',
#   'hallway',
#   'bedroom',
#   'kitchen',
#   'kitchen',
#   'office',
#   'bathroom',
#   'office',
#   'bedroom',
#   'bedroom',
#   'office',
#   'kitchen',
#   'bedroom',
#   'bathroom',
#   'bathroom',
#   'bedroom',
#   'bathroom',
#   'office',
#   'hallway',
#   'bathroom',
#   'office',
#   'kitchen',
#   'garden',
#   'hallway',
#   'garden',
#   'bathroom',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'office',
#   'hallway',
#   'kitchen',
#   'garden',
#   'hallway',
#   'garden',
#   'office',
#   'office',
#   'hallway',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'kitchen',
#   'kitchen',
#   'office',
#   'hallway',
#   'bedroom',
#   'kitchen',
#   'hallway',
#   'hallway',
#   'office',
#   'bedroom',
#   'bathroom',
#   'hallway',
#   'bathroom',
#   'bathroom',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'office',
#   'bathroom',
#   'garden',
#   'garden',
#   'office',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'garden',
#   'hallway',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'office',
#   'hallway',
#   'office',
#   'kitchen',
#   'office',
#   'bathroom',
#   'office',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'kitchen',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'garden',
#   'hallway',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'bedroom',
#   'garden',
#   'bathroom',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'bedroom',
#   'bathroom',
#   'kitchen',
#   'garden',
#   'bedroom',
#   'kitchen',
#   'bathroom',
#   'bedroom',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'kitchen',
#   'office',
#   'garden',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'hallway',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'bathroom',
#   'bedroom',
#   'garden',
#   'garden',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'bedroom',
#   'garden',
#   'office',
#   'office',
#   'office',
#   'garden',
#   'bathroom',
#   'bedroom',
#   'office',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'garden',
#   'bathroom',
#   'garden',
#   'garden',
#   'kitchen',
#   'garden',
#   'bathroom',
#   'kitchen',
#   'office',
#   'office',
#   'garden',
#   'garden',
#   'garden',
#   'office',
#   'garden',
#   'garden',
#   'garden',
#   'garden',
#   'garden',
#   'garden',
#   'kitchen',
#   'garden',
#   'hallway',
#   'kitchen',
#   'garden',
#   'bedroom',
#   'garden',
#   'bedroom',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'garden',
#   'bathroom',
#   'bathroom',
#   'office',
#   'garden',
#   'kitchen',
#   'kitchen',
#   'kitchen',
#   'office',
#   'office',
#   'office',
#   'hallway',
#   'office',
#   'bedroom',
#   'hallway',
#   'bathroom',
#   'kitchen',
#   'kitchen',
#   'office',
#   'bathroom',
#   'bathroom',
#   'kitchen',
#   'bedroom',
#   'hallway',
#   'office',
#   'garden',
#   'office',
#   'office',
#   'bathroom',
#   'bathroom',
#   'kitchen',
#   'bedroom',
#   'office',
#   'office',
#   'hallway',
#   'bedroom',
#   'hallway',
#   'garden',
#   'hallway',
#   'garden',
#   'hallway',
#   'office',
#   'hallway',
#   'bathroom',
#   'bedroom',
#   'garden',
#   'hallway',
#   'bathroom',
#   'kitchen',
#   'bathroom',
#   'office',
#   'garden',
#   'garden',
#   'kitchen',
#   'hallway',
#   'garden',
#   'hallway',
#   'office',
#   'garden',
#   'office',
#   'bedroom',
#   'kitchen',
#   'garden',
#   'bathroom',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'hallway',
#   'hallway',
#   'garden',
#   'garden',
#   'garden',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'bedroom',
#   'bathroom',
#   'kitchen',
#   'kitchen',
#   'office',
#   'office',
#   'garden',
#   'bathroom',
#   'bathroom',
#   'garden',
#   'hallway',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'office',
#   'hallway',
#   'office',
#   'hallway',
#   'hallway',
#   'garden',
#   'hallway',
#   'garden',
#   'bedroom',
#   'kitchen',
#   'bedroom',
#   'office',
#   'bathroom',
#   'bathroom',
#   'bedroom',
#   'office',
#   'kitchen',
#   'bedroom',
#   'garden',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'garden',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'hallway',
#   'bedroom',
#   'bedroom',
#   'hallway',
#   'bedroom',
#   'bedroom',
#   'hallway',
#   'garden',
#   'hallway',
#   'hallway',
#   'garden',
#   'garden',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'bedroom',
#   'hallway',
#   'kitchen',
#   'kitchen',
#   'kitchen',
#   'office',
#   'office',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'kitchen',
#   'bedroom',
#   'garden',
#   'bathroom',
#   'hallway',
#   'office',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'office',
#   'bathroom',
#   'office',
#   'hallway',
#   'bedroom',
#   'office',
#   'bedroom',
#   'bathroom',
#   'bathroom',
#   'kitchen',
#   'garden',
#   'office',
#   'hallway',
#   'garden',
#   'kitchen',
#   'garden',
#   'office',
#   'office',
#   'office',
#   'office',
#   'hallway',
#   'office',
#   'kitchen',
#   'office',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'office',
#   'garden',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'hallway',
#   'office',
#   'kitchen',
#   'kitchen',
#   'office',
#   'office',
#   'hallway',
#   'garden',
#   'office',
#   'office',
#   'office',
#   'garden',
#   'office',
#   'bathroom',
#   'bedroom',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'hallway',
#   'office',
#   'garden',
#   'hallway',
#   'bedroom',
#   'bathroom',
#   'kitchen',
#   'office',
#   'garden',
#   'bathroom',
#   'bedroom',
#   'kitchen',
#   'hallway',
#   'bathroom',
#   'garden',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'garden',
#   'bedroom',
#   'kitchen',
#   'kitchen',
#   'bedroom',
#   'garden',
#   'bedroom',
#   'office',
#   'kitchen',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'office',
#   'office',
#   'bathroom',
#   'office',
#   'office',
#   'garden',
#   'garden',
#   'hallway',
#   'bedroom',
#   'garden',
#   'kitchen',
#   'office',
#   'office',
#   'office',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'hallway',
#   'hallway',
#   'garden',
#   'bedroom',
#   'office',
#   'office',
#   'office',
#   'garden',
#   'hallway',
#   'garden',
#   'office',
#   'bathroom',
#   'hallway',
#   'bedroom',
#   'kitchen',
#   'garden',
#   'office',
#   'kitchen',
#   'kitchen',
#   'garden',
#   'bathroom',
#   'garden',
#   'office',
#   'garden',
#   'bathroom',
#   'garden',
#   'garden',
#   'office',
#   'kitchen',
#   'garden',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'office',
#   'hallway',
#   'office',
#   'kitchen',
#   'kitchen',
#   'kitchen',
#   'bedroom',
#   'garden',
#   'hallway',
#   'office',
#   'hallway',
#   'bedroom',
#   'kitchen',
#   'kitchen',
#   'hallway',
#   'hallway',
#   'kitchen',
#   'kitchen',
#   'kitchen',
#   'hallway',
#   'bathroom',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'office',
#   'office',
#   'hallway',
#   'garden',
#   'hallway',
#   'bedroom',
#   'bathroom',
#   'bedroom',
#   'garden',
#   'office',
#   'bathroom',
#   'bathroom',
#   'hallway',
#   'garden',
#   'bathroom',
#   'office',
#   'kitchen',
#   'bedroom',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'office',
#   'hallway',
#   'hallway',
#   'office',
#   'bathroom',
#   'hallway',
#   'kitchen',
#   'office',
#   'bedroom',
#   'bedroom',
#   'garden',
#   'office',
#   'kitchen',
#   'bedroom',
#   'bathroom',
#   'garden',
#   'hallway',
#   'bedroom',
#   'bedroom',
#   'garden',
#   'garden',
#   'office',
#   'garden',
#   'garden',
#   'kitchen',
#   'garden',
#   'hallway',
#   'hallway',
#   'bathroom',
#   'office',
#   'bathroom',
#   'hallway',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'garden',
#   'garden',
#   'kitchen',
#   'kitchen',
#   'bedroom',
#   'office',
#   'office',
#   'kitchen',
#   'bathroom',
#   'garden',
#   'office',
#   'garden',
#   'garden',
#   'hallway',
#   'kitchen',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'bedroom',
#   'kitchen',
#   'hallway',
#   'office',
#   'kitchen',
#   'kitchen',
#   'office',
#   'office',
#   'office',
#   'bedroom',
#   'kitchen',
#   'bedroom',
#   'bathroom',
#   'bedroom',
#   'office',
#   'bedroom',
#   'hallway',
#   'bedroom',
#   'kitchen',
#   'office',
#   'kitchen',
#   'garden',
#   'garden',
#   'bedroom',
#   'office',
#   'kitchen',
#   'garden',
#   'garden',
#   'garden',
#   'garden',
#   'garden',
#   'kitchen',
#   'bathroom',
#   'hallway',
#   'kitchen',
#   'kitchen',
#   'kitchen',
#   'garden',
#   'kitchen',
#   'kitchen',
#   'garden',
#   'bathroom',
#   'kitchen',
#   'office',
#   'hallway',
#   'office',
#   'kitchen',
#   'bedroom',
#   'hallway',
#   'kitchen',
#   'kitchen',
#   'office',
#   'office',
#   'office',
#   'office',
#   'bedroom',
#   'kitchen',
#   'garden',
#   'bedroom',
#   'bedroom',
#   'office',
#   'bedroom',
#   'garden',
#   ...])

# %%
def vectorize(data, word2idx, story_maxlen, question_maxlen):
    Xs, Xq, Y = [], [], []
    stories,questions,answers= data
    for story, question, answer in zip(stories, questions, answers):
        xs = [[word2idx[w.lower()] for w in nltk.word_tokenize(s)] 
                   for s in story]
        xs = list(itertools.chain.from_iterable(xs))
        xq = [word2idx[w.lower()] for w in nltk.word_tokenize(question)]
        Xs.append(xs)
        Xq.append(xq)
        Y.append(word2idx[answer.lower()])
    return pad_sequences(Xs, maxlen=story_maxlen),pad_sequences(Xq, maxlen=question_maxlen),np_utils.to_categorical(Y, num_classes=len(word2idx))

Xstrain, Xqtrain, Ytrain = vectorize(data_train, word2idx, story_maxlen, question_maxlen)
Xstest, Xqtest, Ytest = vectorize(data_test, word2idx, story_maxlen, question_maxlen)

# %%
EMBEDDING_SIZE = 64
LATENT_SIZE = 32

# inputs
story_input = Input(shape=(story_maxlen,))
question_input = Input(shape=(question_maxlen,))

# story encoder memory
story_encoder = Embedding(input_dim=vocab_size,
output_dim=EMBEDDING_SIZE,
    input_length=story_maxlen)(story_input)
story_encoder = Dropout(0.3)(story_encoder)

# question encoder
question_encoder = Embedding(input_dim=vocab_size,
output_dim=EMBEDDING_SIZE,
    input_length=question_maxlen)(question_input)
question_encoder = Dropout(0.3)(question_encoder)

# match between story and question
match = dot([story_encoder, question_encoder], axes=[2, 2])

# encode story into vector space of question
story_encoder_c = Embedding(input_dim=vocab_size,
output_dim=question_maxlen,
    input_length=story_maxlen)(story_input)
story_encoder_c = Dropout(0.3)(story_encoder_c)

# combine match and story vectors
response = add([match, story_encoder_c])
response = Permute((2, 1))(response)

# combine response and question vectors
answer = concatenate([response, question_encoder], axis=-1)
answer = LSTM(LATENT_SIZE)(answer)
answer = Dropout(0.3)(answer)
answer = Dense(vocab_size)(answer)
output = Activation("softmax")(answer)

model = Model(inputs=[story_input, question_input], outputs=output)
model.summary()
model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 14)           0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 4)            0
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 14, 64)       1408        input_5[0][0]
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 4, 64)        1408        input_6[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 14, 64)       0           embedding_7[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 4, 64)        0           embedding_8[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 14, 4)        88          input_5[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 14, 4)        0           dropout_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 14, 4)        0           embedding_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 4)        0           dot_3[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 4, 14)        0           add_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 4, 78)        0           permute_3[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 32)           14208       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32)           0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 22)           726         dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 22)           0           dense_2[0][0]
# ==================================================================================================
# Total params: 17,838
# Trainable params: 17,838
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 32
NUM_EPOCHS = 50
history = model.fit([Xstrain, Xqtrain], [Ytrain], batch_size=BATCH_SIZE,epochs=NUM_EPOCHS,validation_data=([Xstest, Xqtest], [Ytest]))
# Out:
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/50
# 10000/10000 [==============================] - 4s 358us/step - loss: 1.8934 - acc: 0.2281 - val_loss: 1.6252 - val_acc: 0.3422
# Epoch 2/50
# 10000/10000 [==============================] - 2s 217us/step - loss: 1.6303 - acc: 0.3336 - val_loss: 1.5504 - val_acc: 0.4069
# Epoch 3/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 1.5432 - acc: 0.4160 - val_loss: 1.4427 - val_acc: 0.5193
# Epoch 4/50
# 10000/10000 [==============================] - 2s 216us/step - loss: 1.4633 - acc: 0.4746 - val_loss: 1.3766 - val_acc: 0.5300
# Epoch 5/50
# 10000/10000 [==============================] - 2s 218us/step - loss: 1.4174 - acc: 0.4980 - val_loss: 1.3328 - val_acc: 0.5368
# Epoch 6/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 1.3713 - acc: 0.5105 - val_loss: 1.2953 - val_acc: 0.5380
# Epoch 7/50
# 10000/10000 [==============================] - 2s 221us/step - loss: 1.3454 - acc: 0.5137 - val_loss: 1.2693 - val_acc: 0.5394
# Epoch 8/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 1.3146 - acc: 0.5138 - val_loss: 1.2423 - val_acc: 0.5446
# Epoch 9/50
# 10000/10000 [==============================] - 2s 219us/step - loss: 1.3032 - acc: 0.5147 - val_loss: 1.2229 - val_acc: 0.5465
# Epoch 10/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 1.2845 - acc: 0.5172 - val_loss: 1.2110 - val_acc: 0.5521
# Epoch 11/50
# 10000/10000 [==============================] - 2s 216us/step - loss: 1.2687 - acc: 0.5294 - val_loss: 1.1938 - val_acc: 0.5628
# Epoch 12/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 1.2443 - acc: 0.5441 - val_loss: 1.1540 - val_acc: 0.5993
# Epoch 13/50
# 10000/10000 [==============================] - 2s 216us/step - loss: 1.2127 - acc: 0.5719 - val_loss: 1.1013 - val_acc: 0.6334
# Epoch 14/50
# 10000/10000 [==============================] - 2s 217us/step - loss: 1.1574 - acc: 0.6098 - val_loss: 1.0402 - val_acc: 0.6656
# Epoch 15/50
# 10000/10000 [==============================] - 2s 221us/step - loss: 1.1109 - acc: 0.6346 - val_loss: 0.9869 - val_acc: 0.6904
# Epoch 16/50
# 10000/10000 [==============================] - 2s 226us/step - loss: 1.0578 - acc: 0.6582 - val_loss: 0.9043 - val_acc: 0.7228
# Epoch 17/50
# 10000/10000 [==============================] - 2s 228us/step - loss: 0.9886 - acc: 0.6908 - val_loss: 0.8245 - val_acc: 0.7533
# Epoch 18/50
# 10000/10000 [==============================] - 2s 223us/step - loss: 0.9158 - acc: 0.7173 - val_loss: 0.7551 - val_acc: 0.7738
# Epoch 19/50
# 10000/10000 [==============================] - 2s 219us/step - loss: 0.8571 - acc: 0.7372 - val_loss: 0.6973 - val_acc: 0.7792
# Epoch 20/50
# 10000/10000 [==============================] - 2s 227us/step - loss: 0.7992 - acc: 0.7512 - val_loss: 0.6526 - val_acc: 0.7840
# Epoch 21/50
# 10000/10000 [==============================] - 2s 228us/step - loss: 0.7546 - acc: 0.7582 - val_loss: 0.6183 - val_acc: 0.7884
# Epoch 22/50
# 10000/10000 [==============================] - 2s 233us/step - loss: 0.7024 - acc: 0.7674 - val_loss: 0.5767 - val_acc: 0.7908
# Epoch 23/50
# 10000/10000 [==============================] - 2s 228us/step - loss: 0.6681 - acc: 0.7727 - val_loss: 0.5477 - val_acc: 0.7900
# Epoch 24/50
# 10000/10000 [==============================] - 2s 225us/step - loss: 0.6403 - acc: 0.7788 - val_loss: 0.5244 - val_acc: 0.7939
# Epoch 25/50
# 10000/10000 [==============================] - 2s 238us/step - loss: 0.6157 - acc: 0.7768 - val_loss: 0.5086 - val_acc: 0.7959
# Epoch 26/50
# 10000/10000 [==============================] - 2s 249us/step - loss: 0.5925 - acc: 0.7804 - val_loss: 0.4957 - val_acc: 0.7966
# Epoch 27/50
# 10000/10000 [==============================] - 3s 263us/step - loss: 0.5734 - acc: 0.7810 - val_loss: 0.4830 - val_acc: 0.7989
# Epoch 28/50
# 10000/10000 [==============================] - 3s 264us/step - loss: 0.5645 - acc: 0.7817 - val_loss: 0.4759 - val_acc: 0.7990
# Epoch 29/50
# 10000/10000 [==============================] - 2s 230us/step - loss: 0.5414 - acc: 0.7862 - val_loss: 0.4692 - val_acc: 0.7984
# Epoch 30/50
# 10000/10000 [==============================] - 2s 219us/step - loss: 0.5307 - acc: 0.7874 - val_loss: 0.4644 - val_acc: 0.8026
# Epoch 31/50
# 10000/10000 [==============================] - 2s 219us/step - loss: 0.5218 - acc: 0.7898 - val_loss: 0.4597 - val_acc: 0.8061
# Epoch 32/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 0.5174 - acc: 0.7905 - val_loss: 0.4570 - val_acc: 0.8068
# Epoch 33/50
# 10000/10000 [==============================] - 2s 224us/step - loss: 0.5184 - acc: 0.7889 - val_loss: 0.4539 - val_acc: 0.8088
# Epoch 34/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 0.5060 - acc: 0.7913 - val_loss: 0.4517 - val_acc: 0.8079
# Epoch 35/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 0.4994 - acc: 0.7901 - val_loss: 0.4492 - val_acc: 0.8130
# Epoch 36/50
# 10000/10000 [==============================] - 2s 219us/step - loss: 0.4943 - acc: 0.7924 - val_loss: 0.4485 - val_acc: 0.8103
# Epoch 37/50
# 10000/10000 [==============================] - 2s 220us/step - loss: 0.4917 - acc: 0.7925 - val_loss: 0.4468 - val_acc: 0.8137
# Epoch 38/50
# 10000/10000 [==============================] - 2s 222us/step - loss: 0.4825 - acc: 0.7979 - val_loss: 0.4459 - val_acc: 0.8145
# Epoch 39/50
# 10000/10000 [==============================] - 2s 218us/step - loss: 0.4841 - acc: 0.7978 - val_loss: 0.4430 - val_acc: 0.8145
# Epoch 40/50
# 10000/10000 [==============================] - 2s 219us/step - loss: 0.4839 - acc: 0.7986 - val_loss: 0.4421 - val_acc: 0.8118
# Epoch 41/50
# 10000/10000 [==============================] - 2s 222us/step - loss: 0.4832 - acc: 0.7945 - val_loss: 0.4410 - val_acc: 0.8168
# Epoch 42/50
# 10000/10000 [==============================] - 2s 231us/step - loss: 0.4781 - acc: 0.7961 - val_loss: 0.4398 - val_acc: 0.8169
# Epoch 43/50
# 10000/10000 [==============================] - 2s 219us/step - loss: 0.4798 - acc: 0.7977 - val_loss: 0.4401 - val_acc: 0.8143
# Epoch 44/50
# 10000/10000 [==============================] - 2s 217us/step - loss: 0.4771 - acc: 0.7999 - val_loss: 0.4381 - val_acc: 0.8155
# Epoch 45/50
# 10000/10000 [==============================] - 2s 215us/step - loss: 0.4715 - acc: 0.8003 - val_loss: 0.4367 - val_acc: 0.8190
# Epoch 46/50
# 10000/10000 [==============================] - 2s 219us/step - loss: 0.4718 - acc: 0.7996 - val_loss: 0.4370 - val_acc: 0.8182
# Epoch 47/50
# 10000/10000 [==============================] - 2s 223us/step - loss: 0.4725 - acc: 0.8020 - val_loss: 0.4354 - val_acc: 0.8197
# Epoch 48/50
# 10000/10000 [==============================] - 2s 218us/step - loss: 0.4693 - acc: 0.7998 - val_loss: 0.4354 - val_acc: 0.8171
# Epoch 49/50
# 10000/10000 [==============================] - 2s 223us/step - loss: 0.4696 - acc: 0.8014 - val_loss: 0.4331 - val_acc: 0.8217
# Epoch 50/50
# 10000/10000 [==============================] - 2s 213us/step - loss: 0.4690 - acc: 0.8008 - val_loss: 0.4330 - val_acc: 0.8227

# %%
ytest = np.argmax(Ytest, axis=1)
Ytest_ = model.predict([Xstest, Xqtest])
ytest_ = np.argmax(Ytest_, axis=1)

for i in range(15):
    story = " ".join([idx2word[x] for x in Xstest[i].tolist() if x != 0])
    question = " ".join([idx2word[x] for x in Xqtest[i].tolist()])
    label = idx2word[ytest[i]]
    prediction = idx2word[ytest_[i]]
    print(story, question,'\nLABEL', label, '\nMODEL PREDICTION', prediction)
# Out:
# anirban moved to the bathroom . john went to the hallway . where is anirban ?
# LABEL bathroom
# MODEL PREDICTION bathroom
# daniel went back to the hallway . sandra moved to the garden . where is daniel ?
# LABEL hallway
# MODEL PREDICTION hallway
# john moved to the office . sandra journeyed to the bathroom . where is daniel ?
# LABEL hallway
# MODEL PREDICTION bedroom
# anirban moved to the hallway . daniel travelled to the office . where is daniel ?
# LABEL office
# MODEL PREDICTION office
# john went back to the garden . john moved to the bedroom . where is sandra ?
# LABEL bathroom
# MODEL PREDICTION office
# sandra travelled to the office . sandra went to the bathroom . where is sandra ?
# LABEL bathroom
# MODEL PREDICTION bathroom
# anirban went to the bedroom . daniel moved to the hallway . where is sandra ?
# LABEL bathroom
# MODEL PREDICTION office
# john went to the garden . john travelled to the office . where is sandra ?
# LABEL bathroom
# MODEL PREDICTION garden
# daniel journeyed to the bedroom . daniel travelled to the hallway . where is john ?
# LABEL office
# MODEL PREDICTION bathroom
# john went to the bedroom . john travelled to the office . where is daniel ?
# LABEL hallway
# MODEL PREDICTION office
# anirban went to the bedroom . john journeyed to the bathroom . where is john ?
# LABEL bathroom
# MODEL PREDICTION bathroom
# sandra journeyed to the hallway . john journeyed to the garden . where is anirban ?
# LABEL bedroom
# MODEL PREDICTION kitchen
# john journeyed to the bathroom . sandra journeyed to the garden . where is john ?
# LABEL bathroom
# MODEL PREDICTION bathroom
# sandra went back to the bedroom . daniel travelled to the bathroom . where is john ?
# LABEL bathroom
# MODEL PREDICTION kitchen
# john went to the office . anirban moved to the office . where is sandra ?
# LABEL bedroom
# MODEL PREDICTION office

# %%
#data1=[['Mary moved to the office'],['Where is Mary?'],['office']]
#Xstrain, Xqtrain, Ytrain = vectorize(data_train, word2idx, story_maxlen, question_maxlen)
Xstest, Xqtest, Ytest = vectorize(data1, word2idx, story_maxlen, question_maxlen)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-8376a6c7c62f> in <module>()
#       1 data1=[['Mary moved to the office'],['Where is Mary?'],['office']]
#       2 #Xstrain, Xqtrain, Ytrain = vectorize(data_train, word2idx, story_maxlen, question_maxlen)
# ----> 3 Xstest, Xqtest, Ytest = vectorize(data1, word2idx, story_maxlen, question_maxlen)
#
# <ipython-input-72-2c3cff25cd2d> in vectorize(data, word2idx, story_maxlen, question_maxlen)
#       4     for story, question, answer in zip(stories, questions, answers):
#       5         xs = [[word2idx[w.lower()] for w in nltk.word_tokenize(s)]
# ----> 6                    for s in story]
#       7         xs = list(itertools.chain.from_iterable(xs))
#       8         xq = [word2idx[w.lower()] for w in nltk.word_tokenize(question)]
#
# <ipython-input-72-2c3cff25cd2d> in <listcomp>(.0)
#       4     for story, question, answer in zip(stories, questions, answers):
#       5         xs = [[word2idx[w.lower()] for w in nltk.word_tokenize(s)]
# ----> 6                    for s in story]
#       7         xs = list(itertools.chain.from_iterable(xs))
#       8         xq = [word2idx[w.lower()] for w in nltk.word_tokenize(question)]
#
# <ipython-input-72-2c3cff25cd2d> in <listcomp>(.0)
#       3     stories,questions,answers= data
#       4     for story, question, answer in zip(stories, questions, answers):
# ----> 5         xs = [[word2idx[w.lower()] for w in nltk.word_tokenize(s)]
#       6                    for s in story]
#       7         xs = list(itertools.chain.from_iterable(xs))
#
# KeyError: 'm'
